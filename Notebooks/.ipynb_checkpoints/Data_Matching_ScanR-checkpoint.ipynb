# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import cdist

# %%
# 
def match_nuclei_datasets(dataset_Cellpose_path, dataset_ScanR_path, tolerance=10, 
                          x_col_cellpose='nucleus_centroid_x', y_col_cellpose='nucleus_centroid_y',
                          x_col_ScanR='nucleus_centroid_x', y_col_ScanR='nucleus_centroid_y'):
    """
    Match nuclei between two datasets based on centroid proximity.
    
    Parameters:
    -----------
    dataset1_path : str
        Path to first CSV file (e.g., your program's output)
    dataset2_path : str
        Path to second CSV file (e.g., other program's output)
    tolerance : float
        Maximum distance (in pixels) for nuclei to be considered a match
    x_col_cellpose, y_col_cellpose : str
        Column names for x,y coordinates in dataset 1
    x_col_ScanR, y_col_ScanR : str
        Column names for x,y coordinates in dataset 2
    
    Returns:
    --------
    pd.DataFrame
        Combined DataFrame with matched and unmatched nuclei from both datasets
    """
    
    # Load both datasets
    df1 = pd.read_csv(dataset_Cellpose_path)
    df2 = pd.read_csv(dataset_ScanR_path)
    
    # Add source labels
    df1['source'] = 'Cellpose'
    df2['source'] = 'ScanR'
    
    # Extract coordinates
    coords_Cellpose = df1[[y_col_cellpose, x_col_cellpose]].values
    coords_ScanR = df2[[y_col_ScanR, x_col_ScanR]].values
    
    # Calculate pairwise distances between all nuclei
    distances = cdist(coords_Cellpose, coords_ScanR)
    
    # Find matches within tolerance
    matched_pairs = []
    matched_idx1 = set()
    matched_idx2 = set()
    
    # For each nucleus in dataset1, find closest match in dataset2
    for i in range(len(coords_Cellpose)):
        min_dist_idx = np.argmin(distances[i, :])
        min_dist = distances[i, min_dist_idx]
        
        if min_dist <= tolerance:
            # Check if this is also the closest match from dataset2's perspective
            if np.argmin(distances[:, min_dist_idx]) == i:
                matched_pairs.append({
                    'idx1': i,
                    'idx2': min_dist_idx,
                    'distance': min_dist
                })
                matched_idx1.add(i)
                matched_idx2.add(min_dist_idx)
    
    # Create combined dataframe
    result_rows = []
    
    # 1. Add CONFIRMED nuclei (matched between both datasets)
    print(f"Found {len(matched_pairs)} confirmed matches")
    for match in matched_pairs:
        row1 = df1.iloc[match['idx1']].to_dict()
        row2 = df2.iloc[match['idx2']].to_dict()
        
        combined_row = {
            'status': 'CONFIRMED',
            'match_distance': match['distance'],
            'source': 'Both',
            # Dataset 1 data (prefix with d1_)
            **{f'd1_{k}': v for k, v in row1.items() if k != 'source'},
            # Dataset 2 data (prefix with d2_)
            **{f'd2_{k}': v for k, v in row2.items() if k != 'source'}
        }
        result_rows.append(combined_row)
    
    # 2. Add UNCONFIRMED nuclei from Dataset 1
    unmatched1 = [i for i in range(len(df1)) if i not in matched_idx1]
    print(f"Found {len(unmatched1)} unconfirmed nuclei in Dataset1")
    for i in unmatched1:
        row = df1.iloc[i].to_dict()
        combined_row = {
            'status': 'UNCONFIRMED',
            'match_distance': np.nan,
            'source': 'Dataset1_only',
            **{f'd1_{k}': v for k, v in row.items() if k != 'source'},
        }
        result_rows.append(combined_row)
    
    # 3. Add UNCONFIRMED nuclei from Dataset 2
    unmatched2 = [i for i in range(len(df2)) if i not in matched_idx2]
    print(f"Found {len(unmatched2)} unconfirmed nuclei in Dataset2")
    for i in unmatched2:
        row = df2.iloc[i].to_dict()
        combined_row = {
            'status': 'UNCONFIRMED',
            'match_distance': np.nan,
            'source': 'Dataset2_only',
            **{f'd2_{k}': v for k, v in row.items() if k != 'source'},
        }
        result_rows.append(combined_row)
    
    # Create final DataFrame
    result_df = pd.DataFrame(result_rows)
    
    # Print summary statistics
    print("\nData_Summary")
    print("\n------------")
    print(f"Total nuclei in Dataset1: {len(df1)}")
    print(f"Total nuclei in Dataset2: {len(df2)}")
    print(f"Confirmed matches: {len(matched_pairs)}")
    print(f"Unmatched in Dataset1: {len(unmatched1)}")
    print(f"Unmatched in Dataset2: {len(unmatched2)}")
    print(f"Total rows in result: {len(result_df)}")
    
    return result_df

# %%
# Example usage:
if __name__ == "__main__":
    # Match nuclei with 10-pixel tolerance
    matched_df = match_nuclei_datasets(
        dataset1_path='path/to/your_nucleus_data.csv',
        dataset2_path='path/to/other_program_data.csv',
        tolerance=10,
        x_col_cellpose='centr_x',  # Adjust to your column names
        y_col_cellpose='centr_y',
        x_col_ScanR='Center X',  # Adjust to other program's column names
        y_col_ScanR='Center Y'
    )
    
    # Save results
    matched_df.to_csv('nuclei_comparison_results.csv', index=False)
    
    # Optional: Analyze matched vs unmatched
    confirmed = matched_df[matched_df['status'] == 'CONFIRMED']
    print(f"\nAverage match distance: {confirmed['match_distance'].mean():.2f} pixels")
    
    # Compare measurements for matched nuclei
    if len(confirmed) > 0:
        print("\nComparing nucleus areas for matched nuclei:")
        area_diff = confirmed['d1_nucleus_area'] - confirmed['d2_nucleus_area']
        print(f"Mean area difference: {area_diff.mean():.2f} pixels²")
        print(f"Std area difference: {area_diff.std():.2f} pixels²")
