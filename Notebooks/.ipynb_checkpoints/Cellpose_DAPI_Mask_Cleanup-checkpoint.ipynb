# %%
# Import

from skimage import io, measure
from glob import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# Data loading --> Choosing a folder

folder_path = r'Y:\Group Members\Valentin Aubry\01_Data\Test_Data_Andreas\data'  # The r in r'Example\Pathway' is very important to get the raw input


# Check if the folder is empty or even exists
if os.path.isdir(folder_path) == True:
    print("Folder Path exists")

    # Getting the list of directories
    dir = os.listdir(folder_path)
    
    # Checking if the list is empty or not
    if len(dir) == 0:
        print("Empty directory")
    else:
        print("Not empty directory")
else:
    print("Folder path not found")
# Out:
# Folder Path exists
# Not empty directory

# %%
# Data Loading --> Loading folder content

DAPI_mask_data = glob(os.path.join(folder_path, '*DAPI SEM_seg.npy'))
DAPI_mask_data.sort()


for mask_path in DAPI_mask_data:
    print(os.path.basename(mask_path))
# Out:
# ATR1_24h--W00032--P00001--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00002--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00003--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00004--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00005--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00006--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00007--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00008--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00009--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00010--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00011--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00012--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00013--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00014--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00015--Z00000--T00000--DAPI SEM_seg.npy
# ATR1_24h--W00032--P00016--Z00000--T00000--DAPI SEM_seg.npy
# ...

# %%
# Cellpose DAPI Mask Cleanup High Throughput
# This script cleans up masks that were generated by cellpose by removing all the 
# nuclei that touch the border of the picture and all fragments below a size threshold


#timer to measure how long it takes
start_time = time.time()

all_areas = []
all_areas_noborder = []
all_areas_clean = []


for i in range (len(DAPI_mask_data)):
    # Try to load as dictionary (original Cellpose format) or plain array (already cleaned)
    loaded_data = np.load(DAPI_mask_data[i], allow_pickle=True)
    
    # Try to load it as an output from Cellpose
    try:
        mask_dict = loaded_data.item()
        mask = mask_dict['masks']
    # If it isn't an output from Cellpose, but a plain array
    except (ValueError, AttributeError):
        mask = loaded_data

    # Calculate the properties (area etc.) for the nuclei
    props = measure.regionprops(mask)
    areas = [region.area for region in props]
    all_areas.append(areas)
    
    
## Removal of the Nuclei that touch the border of the picture
    # Array to later save the nuclei that don't touch the border
    labels_to_keep = []
    for region in props:
        # Getting the coordinates for the borders of the picture
        min_row, min_col, max_row, max_col = region.bbox
        # Checking if the nuclei touch any of the borders
        touches_border = (min_row == 0 or min_col == 0 or 
                          max_row == 2048 or max_col == 2048)
    
        if not touches_border:
            # Save the nuclei that don't touch the border in the above created array
            labels_to_keep.append(region.label)

    # Create a new mask without the nuclei that touch the border as a starting point for the next step
    mask_clean_border = np.zeros_like(mask)

    for label in labels_to_keep:
        # Copy the labels for the nuclei from the old mask to the new one
        mask_clean_border[mask == label] = label
    # Get the properties from the nuclei on the new mask
    props_no_border = measure.regionprops(mask_clean_border)
    areas = [region.area for region in props_no_border]
    all_areas_noborder.append(areas)

## Small fragment cleanup
    # Minimum size for a Nucleus in pixels
    threshold = 1000  

    # Array for saving cleared nuclei later
    labels_final = []
    for region in props_no_border:
        # Keeping only the nuclei that clear the earlier thershold
        if region.area >= threshold:
            labels_final.append(region.label)
    
    # Create final clean mask
    clean_mask = np.zeros_like(mask)
    for label in labels_final:
        # Copy the Nuclei that passed both requirements
        clean_mask[mask_clean_border == label] = label
 

    # Create an empty array with the same dimensions like the clean_mask
    clean_mask_renumbered = np.zeros_like(clean_mask)

    # Get the unique labels (e.g., [0, 3, 7, 12, 15]) from the clena_mask
    unique_labels = np.unique(clean_mask)
    # Removing the Background from the labels (Background = 0)
    unique_labels = unique_labels[unique_labels != 0]
    
    # Renumber: 3→1, 7→2, 12→3, 15→4
    for new_label, old_label in enumerate(unique_labels, start=1):
        clean_mask_renumbered[clean_mask == old_label] = new_label

    # Calculate the properties (area etc.) for the nuclei
    props_clean = measure.regionprops(clean_mask_renumbered)
    areas = [region.area for region in props_clean]
    all_areas_clean.append(areas)



    # Extract the name of the picture for saving
    base_name = os.path.basename(DAPI_mask_data[i])

    # Saving the cleaned up mask in the same folder where it originated from with the same name (overwriting the old one)
    np.save(folder_path+'/'+base_name, clean_mask_renumbered, allow_pickle=True)



#---------Display------------#
# Flatten all area lists to get global min/max for consistent axes
all_combined = []
for areas in all_areas + all_areas_noborder + all_areas_clean:
    all_combined.extend(areas)

# Calculate axis limits with some padding
y_max = len(DAPI_mask_data) + 0.5  # Number of samples
x_min = 0
x_max = max(all_combined) * 1.1 if all_combined else 5000  # 10% padding

# Create figure with 3 subplots stacked vertically
fig, axes = plt.subplots(3, 1, figsize=(12, 15))

# Plot 1: All areas (original)
for i, areas in enumerate(all_areas):
    axes[0].scatter(areas, [i+1]*len(areas), alpha=0.6, s=20, color='red')
axes[0].set_xlabel('DAPI Area (pixels)', fontsize=12)
axes[0].set_ylabel('Picture Index', fontsize=12)
axes[0].set_title('All Nuclei Areas (Original)', fontsize=14, fontweight='bold')
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(0, y_max)
axes[0].grid(True, alpha=0.3)

# Plot 2: Areas without border nuclei
for i, areas in enumerate(all_areas_noborder):
    axes[1].scatter(areas, [i+1]*len(areas), alpha=0.6, s=20, color='orange')
axes[1].set_xlabel('DAPI Area (pixels)', fontsize=12)
axes[1].set_ylabel('Picture Index', fontsize=12)
axes[1].set_title('After Border Removal', fontsize=14, fontweight='bold')
axes[1].set_xlim(x_min, x_max)
axes[1].set_ylim(0, y_max)
axes[1].grid(True, alpha=0.3)

# Plot 3: Clean areas (after size threshold)
for i, areas in enumerate(all_areas_clean):
    axes[2].scatter(areas, [i+1]*len(areas), alpha=0.6, s=20, color='green')
axes[2].set_xlabel('DAPI Area (pixels)', fontsize=12)
axes[2].set_ylabel('Picture Index', fontsize=12)
axes[2].set_title('After Size Threshold (>1000 pixels)', fontsize=14, fontweight='bold')
axes[2].set_xlim(x_min, x_max)
axes[2].set_ylim(0, y_max)
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Optional: Print summary statistics
print(f"\nSummary Statistics:")
print(f"Total samples: {len(DAPI_mask_data)}")
print(f"X-axis range: {x_min} - {x_max:.0f} pixels")
print(f"Y-axis range: 0 - {y_max:.0f}")
print(f"\nTotal nuclei counts:")
print(f"  Original: {sum(len(a) for a in all_areas)}")
print(f"  After border removal: {sum(len(a) for a in all_areas_noborder)}")
print(f"  After cleanup: {sum(len(a) for a in all_areas_clean)}")



end_time = time.time()
elapsed_time = end_time - start_time

# Convert to minutes and seconds for easier reading
minutes = int(elapsed_time // 60)
seconds = elapsed_time % 60

print(f"Total runtime: {minutes} minutes and {seconds:.2f} seconds")

'''
540 Masks Runtime:
Total runtime: 19 minutes and 57.96 seconds

'''
# Out:
# Summary Statistics:
# Total samples: 540
# X-axis range: 0 - 17868 pixels
# Y-axis range: 0 - 540
#
# Total nuclei counts:
#   Original: 45894
#   After border removal: 40907
#   After cleanup: 38446
# Total runtime: 20 minutes and 26.29 seconds
# '\n540 Masks Runtime:\nTotal runtime: 19 minutes and 57.96 seconds\n\n'

# %%
# Cellpose DAPI Mask Cleanup
mask_dict = np.load(DAPI_mask_data[i], allow_pickle=True).item()
mask = mask_dict['masks']
props = measure.regionprops(mask)


# Nuclei that touch the picture border removal
labels_to_keep = []
for region in props:
    min_row, min_col, max_row, max_col = region.bbox
    touches_border = (min_row == 0 or min_col == 0 or 
                      max_row == 2048 or max_col == 2048)

    if not touches_border:
        labels_to_keep.append(region.label)


mask_clean_border = np.zeros_like(mask)
for label in labels_to_keep:
    mask_clean_border[mask == label] = label

#Get properties of remaining nuclei and plot sizes
props_no_border = measure.regionprops(mask)
areas = [region.area for region in props_no_border]

plt.figure(figsize=(10, 6))
plt.hist(areas, bins=50, edgecolor='black')
plt.xlabel('Nucleus size (pixels)')
plt.ylabel('Count')
plt.title('Size distribution of nuclei')
plt.show()

# %%
# Small fragment cleanup

# Remove nuclei smaller than threshold
threshold = 1000  # Set your threshold based on the histogram

labels_final = []
for region in props_no_border:
    if region.area >= threshold:
        labels_final.append(region.label)

# Create final clean mask
clean_mask = np.zeros_like(mask)
for label in labels_final:
    clean_mask[mask_clean_border == label] = label



#Get properties of remaining nuclei and plot sizes
props_no_border = measure.regionprops(clean_mask)
areas = [region.area for region in props_no_border]

plt.figure(figsize=(10, 6))
plt.hist(areas, bins=50, edgecolor='black')
plt.xlabel('Nucleus size (pixels)')
plt.ylabel('Count')
plt.title('Size distribution of nuclei (small fragments removed)')
plt.show()

# %%
# Full Segmentation Mask
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(36, 24))



# Create a shuffled colormap to randomize colors
np.random.seed(37)  # Makes the colors always the same
num_labels = masks.max()  # Gets the highest number from the nuclei to know how many there are

# Generate random colors for each nucleus (so for 150 nuclei there are 150 colors generated +1 for the background)
colors = plt.cm.gist_ncar(np.linspace(0, 1, num_labels + 1))
np.random.shuffle(colors[1:])  # Shuffle all colors starting at 1 except background (index 0)

# Set background to black: colors[0] to black [R=0, G=0, B=0, Alpha=1] so the background is always black
colors[0] = [0, 0, 0, 1]  

# Create custom colormap, listedColormap takes the array of colors and creates a matplotlib colormap object
custom_cmap = ListedColormap(colors)

# Create display mask with proper color indexing
masks_display = masks.copy()


axes[0].imshow(mask, cmap=custom_cmap) 
axes[0].axis('off')
axes[0].set_title('Original', fontsize = 40)

axes[1].imshow(mask_clean_border, cmap=custom_cmap) 
axes[1].axis('off')
axes[1].set_title('No Border', fontsize = 40)

axes[2].imshow(clean_mask, cmap=custom_cmap) 
axes[2].axis('off')
axes[2].set_title('No Fragments', fontsize = 40)

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Save
np.save('cleaned_mask.npy', clean_mask)

# %%
# Full Segmentation Mask
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(36, 24))

axes.imshow(mask, cmap='nipy_spectral') 
axes.axis('off')
axes.set_title('Original', fontsize = 40)
